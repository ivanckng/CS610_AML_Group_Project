# %% [markdown]
# ### Install and import packages

# %%
import cudf
import numpy as np
import pandas as pd
from PIL import Image
import cv2
import os
import tqdm
from skimage.feature import hog
from cuml.model_selection import train_test_split
from cuml.metrics import accuracy_score

# %%
import cuml
print(cuml.__version__)
# Out:
# 25.02.01

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/cs610')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Image Processing

# %% [markdown]
# #### HOG

# %%
from skimage.feature import hog

def extract_hog_features_recursive(input_dir, pixels_per_cell=(16, 16), cells_per_block=(2, 2)):
    features = []
    filenames = []
    supported_formats = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.webp')
    for root, dirs, files in os.walk(input_dir):
        for filename in files:
            if filename.lower().endswith(supported_formats):
                img_path = os.path.join(root, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None:
                    continue
                # Extract HOG features
                hog_feature = hog(img, pixels_per_cell=pixels_per_cell, cells_per_block=cells_per_block, feature_vector=True)
                features.append(hog_feature)
                rel_path = os.path.relpath(img_path, input_dir)
                filenames.append(rel_path)
    hogged = np.array(features)
    return hogged, filenames

# Example usage:
input_dir = 'grayscale_images'
hogged, filenames = extract_hog_features_recursive(input_dir)
print(hogged.shape)  # (num_images, hog_feature_dim)
# Out:
# (5953, 6084)

# %% [markdown]
# #### Labelling

# %%
y = [f.split(os.sep)[0] for f in filenames]

# %% [markdown]
# #### Data Splitting

# %%
x = hogged.astype(np.float32)
y = np.array(y)
y_encoded, uniques = pd.factorize(y)

# %%
x_train, x_valid, y_encoded_train, y_encoded_valid = train_test_split(x, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)
x_train, x_test, y_encoded_train, y_encoded_test = train_test_split(x_train, y_encoded_train, test_size=0.2, random_state=42, stratify=y_encoded)

# %%
x_train_gpu = cudf.DataFrame(x_train, dtype=np.float32)
y_train_gpu = cudf.Series(y_encoded_train, dtype=np.int32)
x_valid_gpu = cudf.DataFrame(x_valid, dtype=np.float32)
y_valid_gpu = cudf.Series(y_encoded_valid, dtype=np.int32)
x_test_gpu = cudf.DataFrame(x_test, dtype=np.float32)
y_test_gpu = cudf.Series(y_encoded_test, dtype=np.int32)

x_train_cpu = pd.DataFrame(x_train, dtype=np.float32)
y_train_cpu = pd.Series(y_encoded_train, dtype=np.int32)
x_valid_cpu = pd.DataFrame(x_valid, dtype=np.float32)
y_valid_cpu = pd.Series(y_encoded_valid, dtype=np.int32)
x_test_cpu = pd.DataFrame(x_test, dtype=np.float32)
y_test_cpu = pd.Series(y_encoded_test, dtype=np.int32)

# %%
print("Number of Samples:", len(y_train_cpu))
print("Number of Labels:", len(np.unique(y_train_cpu)))

counts = y_train_cpu.value_counts()
print("Label Distribution:")
print(counts)
# Out:
# Number of Samples: 3811
# Number of Labels: 50
# Label Distribution:
# 18    100
# 9      99
# 26     99
# 31     98
# 23     97
# 30     97
# 41     97
# 44     97
# 4      97
# 14     96
# 22     96
# 38     96
# 43     96
# 16     95
# 2      95
# 20     95
# 11     95
# 7      95
# 10     94
# 46     94
# 49     93
# 39     93
# 33     92
# 17     92
# 12     70
# 45     70
# 32     69
# 34     65
# 25     65
# 27     64
# 47     63
# 24     62
# 6      61
# 15     61
# 37     61
# 3      59
# 1      59
# 28     58
# 42     57
# 40     57
# 19     57
# 8      55
# 29     53
# 13     52
# 21     51
# 36     51
# 48     50
# 0      49
# 35     49
# 5      45
# Name: count, dtype: int64

# %% [markdown]
# #### KNN

# %%
# %load_ext cuml.accel
import time
import xgboost as xgb
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.class_weight import compute_sample_weight

# Start timing
start_time = time.time()

# Base model
base_model = cuml.neighbors.KNeighborsClassifier()

# Hyperparameters
param_dist = {
    'n_neighbors': randint(1, 30),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'cosine']
}


# Randomized search tuning
random_search = RandomizedSearchCV(
    base_model,
    param_dist,
    n_iter=50,
    scoring='accuracy',
    cv=5,
    verbose=2,
    random_state=42,
    error_score='raise'
)
random_search.fit(x_train_cpu, y_train_cpu)

# End timing
end_time = time.time()
training_time = end_time - start_time
# Out:
# [2025-06-16 19:29:27.663] [CUML] [info] cuML: Installed accelerator for sklearn.
# [2025-06-16 19:29:38.496] [CUML] [info] cuML: Installed accelerator for umap.
# [2025-06-16 19:29:38.510] [CUML] [info] cuML: Installed accelerator for hdbscan.
# [2025-06-16 19:29:38.510] [CUML] [info] cuML: Successfully initialized accelerator.
# [2025-06-16 19:29:38.530] [CUML] [info] Unused keyword parameter: handle during CPU estimator initialization
# [2025-06-16 19:29:38.530] [CUML] [info] Unused keyword parameter: verbose during CPU estimator initialization
# [2025-06-16 19:29:38.530] [CUML] [info] Unused keyword parameter: output_type during CPU estimator initialization
# [2025-06-16 19:29:38.533] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:38.533] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [2025-06-16 19:29:38.540] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:38.540] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=20, weights=uniform; total time=   0.5s
# [2025-06-16 19:29:39.003] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.003] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=20, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.077] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.077] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=20, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.149] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.149] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=20, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.220] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.220] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=20, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.289] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.289] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:39.359] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.359] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:39.430] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.430] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:39.499] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.499] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:39.566] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.566] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:39.637] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.637] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=21, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.712] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.712] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=21, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.786] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.786] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=21, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.858] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.858] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=21, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:39.941] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:39.942] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=21, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.014] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.014] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.086] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.086] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.156] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.157] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.228] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.228] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.299] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.299] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:40.370] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.370] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.439] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.439] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.510] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.510] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.579] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.579] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.648] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.648] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=11, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.718] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.718] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=4, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.793] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.793] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=4, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.867] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.867] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=4, weights=distance; total time=   0.1s
# [2025-06-16 19:29:40.941] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:40.941] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=4, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.013] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.013] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=4, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.097] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.097] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=22, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:41.167] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.167] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=22, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:41.237] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.237] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=22, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:41.307] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.307] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=22, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:41.379] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.379] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=22, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:41.448] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.448] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .metric=manhattan, n_neighbors=24, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.518] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.518] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .metric=manhattan, n_neighbors=24, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.591] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.591] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .metric=manhattan, n_neighbors=24, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.663] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.663] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .metric=manhattan, n_neighbors=24, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.734] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.734] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .metric=manhattan, n_neighbors=24, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.804] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.804] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=6, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.877] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.877] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=6, weights=distance; total time=   0.1s
# [2025-06-16 19:29:41.948] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:41.948] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=6, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.019] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.019] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=6, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.091] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.091] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=6, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.164] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.164] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.248] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.248] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.319] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.319] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:42.392] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:42.392] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29
[CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:53.694] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ......metric=cosine, n_neighbors=1, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:53.761] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:53.761] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ......metric=cosine, n_neighbors=1, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:53.830] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:53.830] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ......metric=cosine, n_neighbors=1, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:53.897] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:53.897] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ......metric=cosine, n_neighbors=1, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:53.977] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:53.977] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ......metric=cosine, n_neighbors=1, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.044] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.044] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=10, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.117] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.117] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=10, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.191] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.191] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=10, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.262] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.262] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=10, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.334] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.334] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=10, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:54.405] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.405] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.475] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.475] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.545] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.545] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.614] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.614] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.682] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.682] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.753] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.753] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.822] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.822] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.890] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.890] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:54.957] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:54.957] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.026] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.026] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END .....metric=cosine, n_neighbors=9, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.105] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.105] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.176] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.176] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.247] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.247] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.319] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.319] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.389] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.389] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=1, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.459] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.459] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=23, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.528] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.528] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=23, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.598] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.598] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=23, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.667] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.667] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=23, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.735] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.736] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ....metric=cosine, n_neighbors=23, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.803] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.803] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=3, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.877] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.877] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=3, weights=distance; total time=   0.1s
# [2025-06-16 19:29:55.948] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:55.948] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=3, weights=distance; total time=   0.1s
# [2025-06-16 19:29:56.020] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.020] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=3, weights=distance; total time=   0.1s
# [2025-06-16 19:29:56.092] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.092] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=euclidean, n_neighbors=3, weights=distance; total time=   0.1s
# [2025-06-16 19:29:56.165] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.166] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=27, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.246] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.246] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=27, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.316] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.316] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=27, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.388] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.388] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=27, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.458] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.458] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..metric=manhattan, n_neighbors=27, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.529] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.529] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.600] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.600] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.673] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.673] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.746] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.746] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.818] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.818] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.1s
# [2025-06-16 19:29:56.892] [CUML] [info] Unused keyword parameter: leaf_size during cuML estimator initialization
# [2025-06-16 19:29:56.892] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization

# %%
# Best model
best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)
print(f"Best Accuracy: {random_search.best_score_:.6f}", )
print(f"Total Training Time: {training_time/60:.2f} minutes")
# Out:
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# Best Accuracy: 0.271317
# Total Training Time: 0.31 minutes

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, fbeta_score

beta = 0.5  # mis-labelled sneakers are more costly than missing labels

# Predictions
y_pred_train = best_model.predict(x_train_cpu)
y_pred_test = best_model.predict(x_test_cpu)

# --- Train Scores ---
print("TRAIN METRICS")
print("Accuracy:", accuracy_score(y_train_cpu, y_pred_train))
print("Precision (macro):", precision_score(y_train_cpu, y_pred_train, average='macro'))
print("Recall (macro):", recall_score(y_train_cpu, y_pred_train, average='macro'))
print(f"F{beta}-Score (macro):", fbeta_score(y_train_cpu, y_pred_train, beta=beta, average='macro'))

# --- Test Scores ---
print("\n TEST METRICS")
print("Accuracy:", accuracy_score(y_test_cpu, y_pred_test))
print("Precision (macro):", precision_score(y_test_cpu, y_pred_test, average='macro'))
print("Recall (macro):", recall_score(y_test_cpu, y_pred_test, average='macro'))
print(f"F{beta}-Score (macro):", fbeta_score(y_test_cpu, y_pred_test, beta=beta, average='macro'))
# Out:
# TRAIN METRICS
# Accuracy: 0.9981632117554448
# Precision (macro): 0.9975538024564198
# Recall (macro): 0.9975573294089424
# F0.5-Score (macro): 0.9975452255511602
#
#  TEST METRICS
# Accuracy: 0.27941176470588236
# Precision (macro): 0.30356876286853507
# Recall (macro): 0.2732286067098424
# F0.5-Score (macro): 0.28696642446362525
